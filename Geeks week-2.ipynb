# %%
import pandas as pd
# Out:
# C:\Users\vknsr\Anaconda3\lib\site-packages\pandas\core\computation\expressions.py:21: UserWarning: Pandas requires version '2.7.3' or newer of 'numexpr' (version '2.7.1' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED

# %%
df=pd.read_csv("C:/Users/vknsr/Downloads/iris.csv")
df.head()
# Out:
#    sepal.length  sepal.width  petal.length  petal.width variety
# 0           5.1          3.5           1.4          0.2  Setosa
# 1           4.9          3.0           1.4          0.2  Setosa
# 2           4.7          3.2           1.3          0.2  Setosa
# 3           4.6          3.1           1.5          0.2  Setosa
# 4           5.0          3.6           1.4          0.2  Setosa

# %%
df['variety'].head(10)
# Out:
# 0    Setosa
# 1    Setosa
# 2    Setosa
# 3    Setosa
# 4    Setosa
# 5    Setosa
# 6    Setosa
# 7    Setosa
# 8    Setosa
# 9    Setosa
# Name: variety, dtype: object

# %%
df.set_index('petal.width')
# Out:
#              sepal.length  sepal.width  petal.length    variety
# petal.width
# 0.2                   5.1          3.5           1.4     Setosa
# 0.2                   4.9          3.0           1.4     Setosa
# 0.2                   4.7          3.2           1.3     Setosa
# 0.2                   4.6          3.1           1.5     Setosa
# 0.2                   5.0          3.6           1.4     Setosa
# ...                   ...          ...           ...        ...
# 2.3                   6.7          3.0           5.2  Virginica
# 1.9                   6.3          2.5           5.0  Virginica
# 2.0                   6.5          3.0           5.2  Virginica
# 2.3                   6.2          3.4           5.4  Virginica
# 1.8                   5.9          3.0           5.1  Virginica
#
# [150 rows x 4 columns]

# %%
df.values[:,:]
# Out:
# array([[5.1, 3.5, 1.4, 0.2, 'Setosa'],
#        [4.9, 3.0, 1.4, 0.2, 'Setosa'],
#        [4.7, 3.2, 1.3, 0.2, 'Setosa'],
#        [4.6, 3.1, 1.5, 0.2, 'Setosa'],
#        [5.0, 3.6, 1.4, 0.2, 'Setosa'],
#        [5.4, 3.9, 1.7, 0.4, 'Setosa'],
#        [4.6, 3.4, 1.4, 0.3, 'Setosa'],
#        [5.0, 3.4, 1.5, 0.2, 'Setosa'],
#        [4.4, 2.9, 1.4, 0.2, 'Setosa'],
#        [4.9, 3.1, 1.5, 0.1, 'Setosa'],
#        [5.4, 3.7, 1.5, 0.2, 'Setosa'],
#        [4.8, 3.4, 1.6, 0.2, 'Setosa'],
#        [4.8, 3.0, 1.4, 0.1, 'Setosa'],
#        [4.3, 3.0, 1.1, 0.1, 'Setosa'],
#        [5.8, 4.0, 1.2, 0.2, 'Setosa'],
#        [5.7, 4.4, 1.5, 0.4, 'Setosa'],
#        [5.4, 3.9, 1.3, 0.4, 'Setosa'],
#        [5.1, 3.5, 1.4, 0.3, 'Setosa'],
#        [5.7, 3.8, 1.7, 0.3, 'Setosa'],
#        [5.1, 3.8, 1.5, 0.3, 'Setosa'],
#        [5.4, 3.4, 1.7, 0.2, 'Setosa'],
#        [5.1, 3.7, 1.5, 0.4, 'Setosa'],
#        [4.6, 3.6, 1.0, 0.2, 'Setosa'],
#        [5.1, 3.3, 1.7, 0.5, 'Setosa'],
# ...

# %%
df[-5:]
# Out:
#      sepal.length  sepal.width  petal.length  petal.width    variety
# 145           6.7          3.0           5.2          2.3  Virginica
# 146           6.3          2.5           5.0          1.9  Virginica
# 147           6.5          3.0           5.2          2.0  Virginica
# 148           6.2          3.4           5.4          2.3  Virginica
# 149           5.9          3.0           5.1          1.8  Virginica

# %%
df.loc[:,:]
# Out:
#      sepal.length  sepal.width  petal.length  petal.width    variety
# 0             5.1          3.5           1.4          0.2     Setosa
# 1             4.9          3.0           1.4          0.2     Setosa
# 2             4.7          3.2           1.3          0.2     Setosa
# 3             4.6          3.1           1.5          0.2     Setosa
# 4             5.0          3.6           1.4          0.2     Setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  Virginica
# 146           6.3          2.5           5.0          1.9  Virginica
# 147           6.5          3.0           5.2          2.0  Virginica
# 148           6.2          3.4           5.4          2.3  Virginica
# 149           5.9          3.0           5.1          1.8  Virginica
#
# [150 rows x 5 columns]

# %%
df[5:80:6]
# Out:
#     sepal.length  sepal.width  petal.length  petal.width     variety
# 5            5.4          3.9           1.7          0.4      Setosa
# 11           4.8          3.4           1.6          0.2      Setosa
# 17           5.1          3.5           1.4          0.3      Setosa
# 23           5.1          3.3           1.7          0.5      Setosa
# 29           4.7          3.2           1.6          0.2      Setosa
# 35           5.0          3.2           1.2          0.2      Setosa
# 41           4.5          2.3           1.3          0.3      Setosa
# 47           4.6          3.2           1.4          0.2      Setosa
# 53           5.5          2.3           4.0          1.3  Versicolor
# 59           5.2          2.7           3.9          1.4  Versicolor
# 65           6.7          3.1           4.4          1.4  Versicolor
# 71           6.1          2.8           4.0          1.3  Versicolor
# 77           6.7          3.0           5.0          1.7  Versicolor

# %%
df[(df['sepal.length']<5.0) | (df['petal.width']>0.2)]
# Out:
#      sepal.length  sepal.width  petal.length  petal.width    variety
# 1             4.9          3.0           1.4          0.2     Setosa
# 2             4.7          3.2           1.3          0.2     Setosa
# 3             4.6          3.1           1.5          0.2     Setosa
# 5             5.4          3.9           1.7          0.4     Setosa
# 6             4.6          3.4           1.4          0.3     Setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  Virginica
# 146           6.3          2.5           5.0          1.9  Virginica
# 147           6.5          3.0           5.2          2.0  Virginica
# 148           6.2          3.4           5.4          2.3  Virginica
# 149           5.9          3.0           5.1          1.8  Virginica
#
# [133 rows x 5 columns]

# %%
df.rename(columns={'SepalLength':'SepalWidth','PetalLength':'PetalWidth'},inplace=True)
df
# Out:
#      SepalWidth  SepalWidth  PetalWidth  PetalWidth    Variety
# 0           5.1         3.5         1.4         0.2     Setosa
# 1           4.9         3.0         1.4         0.2     Setosa
# 2           4.7         3.2         1.3         0.2     Setosa
# 3           4.6         3.1         1.5         0.2     Setosa
# 4           5.0         3.6         1.4         0.2     Setosa
# ..          ...         ...         ...         ...        ...
# 145         6.7         3.0         5.2         2.3  Virginica
# 146         6.3         2.5         5.0         1.9  Virginica
# 147         6.5         3.0         5.2         2.0  Virginica
# 148         6.2         3.4         5.4         2.3  Virginica
# 149         5.9         3.0         5.1         1.8  Virginica
#
# [150 rows x 5 columns]

# %%
df['SepalWidth'].astype('float')
# Out:
#      SepalWidth  SepalWidth
# 0           5.1         3.5
# 1           4.9         3.0
# 2           4.7         3.2
# 3           4.6         3.1
# 4           5.0         3.6
# ..          ...         ...
# 145         6.7         3.0
# 146         6.3         2.5
# 147         6.5         3.0
# 148         6.2         3.4
# 149         5.9         3.0
#
# [150 rows x 2 columns]

# %%
df.isnull().sum()
# Out:
# SepalWidth    0
# SepalWidth    0
# PetalWidth    0
# PetalWidth    0
# Variety       0
# dtype: int64

# %%
df.groupby('variety').agg({'sepal.width':['mean','median','min','max']})
# Out:
#            sepal.width
#                   mean median  min  max
# variety
# Setosa           3.428    3.4  2.3  4.4
# Versicolor       2.770    2.8  2.0  3.4
# Virginica        2.974    3.0  2.2  3.8

# %%
A=pd.DataFrame({'B':[1,2,3]})
B=pd.DataFrame({'B':[1,2,3]})

# %%
pd.concat([A,B],axis=1)
# Out:
#    A  B
# 0  1  1
# 1  2  2
# 2  3  3

# %%
pd.merge(A,B,on='B',how='inner')
# Out:
#    B
# 0  1
# 1  2
# 2  3

# %%
A.join(B,lsuffix='_left',rsuffix='_right',how='outer')
# Out:
#    B_left  B_right
# 0       1        1
# 1       2        2
# 2       3        3

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df.plot(kind='hist')

# %%
sns.heatmap(df.corr(),annot=True,cmap='crest')
# Out:
# <ipython-input-129-1bd5eb969e50>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr(),annot=True,cmap='crest')

# %%
df['variety'].value_counts().plot(kind='bar')

# %%
sns.lineplot(x='sepal.length',y='sepal.width',data=df)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# Out:
# C:\Users\vknsr\Anaconda3\lib\site-packages\pandas\core\computation\expressions.py:21: UserWarning: Pandas requires version '2.7.3' or newer of 'numexpr' (version '2.7.1' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED

# %%
df=pd.read_csv("C:/Users/vknsr/Downloads/Titanic.csv")
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df['Sex'].value_counts().plot(kind='bar')

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
df['Age'].plot(kind='box').figsize=(15,15)

# %%
df.fillna(df["Age"].mean(),inplace=True)

# %%
df.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Cabin          0
# Embarked       0
# dtype: int64

# %%
import seaborn as sns

# %%
sns.heatmap(df.corr(),annot=True)
# Out:
# <ipython-input-12-8df7bcac526d>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr(),annot=True)

# %%
df['Survived'].value_counts().plot(kind='bar')

# %%
sns.lineplot(x='Sex',y='Survived',data=df)

# %%
df=pd.DataFrame(df)

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex        Age  \
# 0                              Braund, Mr. Owen Harris    male  22.000000
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.000000
# 2                               Heikkinen, Miss. Laina  female  26.000000
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.000000
# 4                             Allen, Mr. William Henry    male  35.000000
# ..                                                 ...     ...        ...
# ...

# %%
df.set_index('PassengerId')
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
# ...               ...     ...
# 887                 0       2
# 888                 1       1
# 889                 0       3
# 890                 1       1
# 891                 0       3
#
#                                                           Name     Sex  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 3                                       Heikkinen, Miss. Laina  female
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 5                                     Allen, Mr. William Henry    male
# ...                                                        ...     ...
# ...

# %%
df[1:10]
# Out:
#    PassengerId  Survived  Pclass  \
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex        Age  \
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.000000
# 2                             Heikkinen, Miss. Laina  female  26.000000
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.000000
# 4                           Allen, Mr. William Henry    male  35.000000
# 5                                   Moran, Mr. James    male  29.699118
# 6                            McCarthy, Mr. Timothy J    male  54.000000
# 7                     Palsson, Master. Gosta Leonard    male   2.000000
# ...

# %%
from sklearn.preprocessing import OneHotEncoder

# %%
ohe=OneHotEnc
